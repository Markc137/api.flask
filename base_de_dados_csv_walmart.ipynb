# %% [markdown]
# <a href="https://colab.research.google.com/github/Markc137/api.flask/blob/main/base_de_dados_csv_walmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/projeto da dio /Walmart_sales.csv')

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df.shape
# Out:
# (6435, 8)

# %%
df.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
df = df.rename(columns={'Store': 'Loja', 'Date': 'Data', 'Weekly_Sales': 'Vendas_Semanal', 'Holiday_Flag': 'Feriado', 'Temperature': 'Temperatura', 'Fuel_Price': 'Preço_combustivel', 'CPI': 'Cpi', 'Unemployment':'Desemprego '})

# %%
df.head()
# Out:
#    Loja        Data  Vendas_Semanal  Feriado  Temperatura  Preço_combustivel  \
# 0     1  05-02-2010      1643690.90        0        42.31              2.572
# 1     1  12-02-2010      1641957.44        1        38.51              2.548
# 2     1  19-02-2010      1611968.17        0        39.93              2.514
# 3     1  26-02-2010      1409727.59        0        46.63              2.561
# 4     1  05-03-2010      1554806.68        0        46.50              2.625
#
#           Cpi  Desemprego
# 0  211.096358        8.106
# 1  211.242170        8.106
# 2  211.289143        8.106
# 3  211.319643        8.106
# 4  211.350143        8.106

# %%
df['Data'] = pd.to_datetime(df['Data']).dt.strftime('%d/%m/%Y')
# Out:
# <ipython-input-111-996a30a38451>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df['Data'] = pd.to_datetime(df['Data']).dt.strftime('%d/%m/%Y')

# %%
df.describe()
# Out:
#               Loja  Vendas_Semanal      Feriado  Temperatura  \
# count  6435.000000    6.435000e+03  6435.000000  6435.000000
# mean     23.000000    1.046965e+06     0.069930    60.663782
# std      12.988182    5.643666e+05     0.255049    18.444933
# min       1.000000    2.099862e+05     0.000000    -2.060000
# 25%      12.000000    5.533501e+05     0.000000    47.460000
# 50%      23.000000    9.607460e+05     0.000000    62.670000
# 75%      34.000000    1.420159e+06     0.000000    74.940000
# max      45.000000    3.818686e+06     1.000000   100.140000
#
#        Preço_combustivel          Cpi  Desemprego
# count        6435.000000  6435.000000  6435.000000
# mean            3.358607   171.578394     7.999151
# std             0.459020    39.356712     1.875885
# min             2.472000   126.064000     3.879000
# 25%             2.933000   131.735000     6.891000
# 50%             3.445000   182.616521     7.874000
# 75%             3.735000   212.743293     8.622000
# ...

# %%
quantidade_lojas = df['Loja'].nunique()

# %%
print(quantidade_lojas)
# Out:
# 45

# %%
df.tail()
# Out:
#       Loja        Data  Vendas_Semanal  Feriado  Temperatura  \
# 6430    45  28/09/2012       713173.95        0        64.88
# 6431    45  10/05/2012       733455.07        0        64.89
# 6432    45  10/12/2012       734464.36        0        54.47
# 6433    45  19/10/2012       718125.53        0        56.47
# 6434    45  26/10/2012       760281.43        0        58.85
#
#       Preço_combustivel         Cpi  Desemprego
# 6430              3.997  192.013558        8.684
# 6431              3.985  192.170412        8.667
# 6432              4.000  192.327265        8.667
# 6433              3.969  192.330854        8.667
# 6434              3.882  192.308899        8.667

# %%
df.head(145)
# Out:
#      Loja       Data  Vendas_Semanal  Feriado  Temperatura  Preço_combustivel  \
# 0       1 2010-05-02      1643690.90        0        42.31              2.572
# 1       1 2010-12-02      1641957.44        1        38.51              2.548
# 2       1 2010-02-19      1611968.17        0        39.93              2.514
# 3       1 2010-02-26      1409727.59        0        46.63              2.561
# 4       1 2010-05-03      1554806.68        0        46.50              2.625
# ..    ...        ...             ...      ...          ...                ...
# 140     1 2012-12-10      1573072.81        0        62.99              3.601
# 141     1 2012-10-19      1508068.77        0        67.97              3.594
# 142     1 2012-10-26      1493659.74        0        69.16              3.506
# 143     2 2010-05-02      2136989.46        0        40.19              2.572
# 144     2 2010-12-02      2137809.50        1        38.49              2.548
#
# ...

# %%
df.isnull().sum()
# Out:
# Loja                 0
# Data                 0
# Vendas_Semanal       0
# Feriado              0
# Temperatura          0
# Preço_combustivel    0
# Cpi                  0
# Desemprego           0
# dtype: int64

# %%
df.sample(20)
# Out:
#       Loja        Data  Vendas_Semanal  Feriado  Temperatura  \
# 4561    32  20/07/2012      1167829.33        0        77.76
# 4018    29  14/05/2010       518940.88        0        50.99
# 1883    14  23/07/2010      2044155.39        0        81.46
# 4550    32  05/04/2012      1187384.53        0        58.29
# 1852    13  14/09/2012      1919917.03        0        68.55
# 6113    43  24/02/2012       613042.97        0        53.53
# 5302    38  23/04/2010       335121.82        0        64.55
# 3412    24  15/06/2012      1364445.98        0        68.28
# 2394    17  17/02/2012       927084.65        0        30.76
# 4906    35  12/10/2010      1108580.19        0        30.83
# 2765    20  01/07/2011      1843030.95        0        31.43
# 5016    36  23/04/2010       434116.80        0        68.03
# 1076     8  15/07/2011       849925.37        0        84.26
# 4991    35  27/07/2012       808030.15        0        76.01
# ...

# %%
df.groupby('Loja')['Vendas_Semanal'].mean().apply(lambda x: f'{x:.2f}')
# Out:
# Loja
# 1     1555264.40
# 2     1925751.34
# 3      402704.44
# 4     2094712.96
# 5      318011.81
# 6     1564728.19
# 7      570617.31
# 8      908749.52
# 9      543980.55
# 10    1899424.57
# 11    1356383.12
# 12    1009001.61
# 13    2003620.31
# 14    2020978.40
# 15     623312.47
# 16     519247.73
# 17     893581.39
# 18    1084718.42
# 19    1444999.04
# 20    2107676.87
# 21     756069.08
# 22    1028501.04
# 23    1389864.46
# 24    1356755.39
# 25     706721.53
# 26    1002911.84
# 27    1775216.20
# 28    1323522.24
# 29     539451.43
# 30     438579.62
# 31    1395901.44
# 32    1166568.15
# 33     259861.69
# 34     966781.56
# 35     919724.98
# 36     373511.99
# 37     518900.28
# 38     385731.65
# 39    1450668.13
# 40     964128.04
# 41    1268125.42
# 42     556403.86
# 43     633324.72
# 44     302748.87
# 45     785981.41
# Name: Vendas_Semanal, dtype: object

# %%
df['Vendas_Semanal'].max()
# Out:
# 3818686.45

# %%
 df.nlargest(5, 'Vendas_Semanal'	)
# Out:
#       Loja        Data  Vendas_Semanal  Feriado  Temperatura  \
# 1905    14  24/12/2010      3818686.45        0        30.59
# 2763    20  24/12/2010      3766687.43        0        25.17
# 1333    10  24/12/2010      3749057.69        0        57.06
# 527      4  23/12/2011      3676388.98        0        35.92
# 1762    13  24/12/2010      3595903.20        0        34.90
#
#       Preço_combustivel         Cpi  Desemprego
# 1905              3.141  182.544590        8.724
# 2763              3.141  204.637673        7.484
# 1333              3.236  126.983581        9.003
# 527               3.103  129.984548        5.143
# 1762              2.846  126.983581        7.795

# %%
df.nsmallest(5, 'Vendas_Semanal')
# Out:
#       Loja        Data  Vendas_Semanal  Feriado  Temperatura  \
# 4619    33  12/03/2010       209986.25        0        52.82
# 4614    33  29/10/2010       213538.32        0        71.34
# 4675    33  30/12/2011       215359.21        1        51.60
# 4623    33  31/12/2010       219804.85        1        52.91
# 4671    33  12/02/2011       220060.35        0        59.12
#
#       Preço_combustivel         Cpi  Desemprego
# 4619              3.041  126.731333        9.265
# 4614              3.130  126.436419        9.265
# 4675              3.428  130.071032        8.010
# 4623              3.148  127.087677        9.265
# 4671              3.701  129.845967        8.010

# %%
df.dtypes
# Out:
# Loja                   int64
# Data                  object
# Vendas_Semanal       float64
# Feriado                int64
# Temperatura          float64
# Preço_combustivel    float64
# Cpi                  float64
# Desemprego           float64
# dtype: object

# %%
df['Data'] = pd.to_datetime(df['Data'], format='%d/%m/%Y')

# %%
df.dtypes
# Out:
# Loja                          int64
# Data                 datetime64[ns]
# Vendas_Semanal              float64
# Feriado                       int64
# Temperatura                 float64
# Preço_combustivel           float64
# Cpi                         float64
# Desemprego                  float64
# dtype: object

# %%
df.groupby(df['Data'].dt.month)['Vendas_Semanal'].sum()
# Out:
# Data
# 1     4.264263e+08
# 2     5.220257e+08
# 3     5.534864e+08
# 4     6.453239e+08
# 5     6.056966e+08
# 6     5.750180e+08
# 7     5.933139e+08
# 8     5.642317e+08
# 9     5.905323e+08
# 10    6.029189e+08
# 11    4.591693e+08
# 12    5.990761e+08
# Name: Vendas_Semanal, dtype: float64

# %%
df.groupby(df['Data'].dt.year)['Vendas_Semanal'].sum()
# Out:
# Data
# 2010    2.288886e+09
# 2011    2.448200e+09
# 2012    2.000133e+09
# Name: Vendas_Semanal, dtype: float64

# %%
df['mês_vendas']= df['Data'].dt.month

# %%
df['Vendas_Ano']= df['Data'].dt.year

# %%
df.sample()
# Out:
#       Loja       Data  Vendas_Semanal  Feriado  Temperatura  \
# 5140    36 2012-07-09       293728.57        1        84.19
#
#       Preço_combustivel         Cpi  Desemprego   mês_vendas  Vendas_Ano
# 5140              3.697  221.118114        6.623           7        2012

# %%
df['Trimestre'] = df['Data'].dt.quarter

# %%
df.sample(5)
# Out:
#       Loja       Data  Vendas_Semanal  Feriado  Temperatura  \
# 5275    37 2012-07-13       506005.47        0        78.15
# 2407    17 2012-05-18       968816.33        0        59.67
# 4932    35 2011-10-06       855130.21        0        73.26
# 4131    29 2012-07-13       514709.76        0        75.81
# 4715    33 2012-05-10       265444.90        0        85.18
#
#       Preço_combustivel         Cpi  Desemprego   mês_vendas  Vendas_Ano  \
# 5275              3.256  220.606344        6.623           7        2012
# 2407              3.808  131.098323        6.235           5        2012
# 4932              3.881  138.860638        8.512          10        2011
# 4131              3.561  138.263000        9.419           7        2012
# 4715              4.132  131.075667        6.895           5        2012
#
#       Trimestre
# 5275          3
# 2407          2
# 4932          4
# 4131          3
# 4715          2

# %%
Vendas_adril_2012 = df.loc[(df['Data'].dt.year == 2012) & (df['Data'].dt.month == 3)]

# %%
Vendas_adril_2012
# Out:
#       Loja       Data  Vendas_Semanal  Feriado  Temperatura  \
# 104      1 2012-03-02      1636339.65        0        56.55
# 110      1 2012-03-16      1677472.78        0        64.74
# 111      1 2012-03-23      1511068.07        0        65.93
# 112      1 2012-03-30      1649604.63        0        67.61
# 130      1 2012-03-08      1631135.79        0        86.11
# ...    ...        ...             ...      ...          ...
# 6396    45 2012-03-02       757330.95        0        42.96
# 6402    45 2012-03-16       788340.23        0        50.56
# 6403    45 2012-03-23       791835.37        0        59.45
# 6404    45 2012-03-30       777254.06        0        50.04
# 6422    45 2012-03-08       725729.51        0        76.58
#
#       Preço_combustivel         Cpi  Desemprego   mês_vendas  Vendas_Ano  \
# 104               3.360  220.172015        7.348           3        2012
# 110               3.734  221.211813        7.348           3        2012
# ...

# %%
vendas_por_mes_ano = df.groupby('mês_vendas')['Vendas_Semanal'].sum()

# %%
vendas_por_mes_ano.plot.bar();
plt.savefig('vendas')

# %%
vendas_por_loja_mes = df.groupby([df['Loja'], df['Data'].dt.month])['Vendas_Semanal'].sum()

# %%
# Salvando e convertendo o arquivo para excel
df.to_excel('de_walmart.xlsx', index=False )
